# %%
import requests as req 
import pandas as pd
from datetime import datetime, timedelta
import time

# %%
API_KEY = #your api key
CHANNEL_ID = #your channel id

# %%
def get_video_stats(video_id):

    url_video_stats = "https://www.googleapis.com/youtube/v3/videos?id="+video_id+"&part=statistics&key="+API_KEY
    response_video_stats = req.get(url_video_stats).json()

    view_count = response_video_stats['items'][0]['statistics']['viewCount']
    like_count = response_video_stats['items'][0]['statistics']['likeCount']
    comment_count = response_video_stats['items'][0]['statistics']['commentCount']
    

    url_video_content = "https://www.googleapis.com/youtube/v3/videos?id="+video_id+"&part=contentDetails&key="+API_KEY
    response_video_content = req.get(url_video_content).json()

    duration = response_video_content['items'][0]['contentDetails']['duration']

    return view_count, like_count, comment_count, duration

# %%
def get_videos(yt_df):
    
    pageToken = ""

    while 1:
        
        url = "https://www.googleapis.com/youtube/v3/search?key="+API_KEY+"&channelId="+CHANNEL_ID+"&part=snippet,id&order=date&maxResults=10000&"+pageToken

        response = req.get(url).json()
        time.sleep(5)

        for video in response['items']:

            if video['id']['kind'] == "youtube#video":

                video_id = video['id']['videoId']
                video_title = video['snippet']['title']
                video_title = str(video_title).replace("&amp;","")
                video_title = str(video_title).replace("é","e")
                video_title = str(video_title).replace("ó","o")
                video_title = str(video_title).replace("&quot","'")
                video_title = str(video_title).replace(";","")
                video_title = str(video_title).replace("&#39","'")
                upload_date = video['snippet']['publishedAt']
                upload_date = upload_date.split('T')[0]

                view_count, like_count, comment_count, duration = get_video_stats(video_id)

                if "El Método Rebord" in video['snippet']['title'] or "El Metodo Rebord" in video['snippet']['title'] or "Cónclave" in video['snippet']['title'] or "Conclave" in video['snippet']['title']:

                    time_string = duration
                    if "S" in time_string:
                        formater = datetime.strptime(time_string, 'PT%HH%MM%SS')
                        normal_time = formater.strftime('%H:%M:%S')
                        duration = normal_time
                    
                    elif "M" in time_string:
                        formater = datetime.strptime(time_string, 'PT%HH%MM')
                        normal_time = formater.strftime('%H:%M:%S')
                        duration = normal_time
                        
                    else:
                        formater = datetime.strptime(time_string, 'PT%HH')
                        normal_time = formater.strftime('%H:%M:%S')
                        duration = normal_time
                        

                    yt_df = yt_df.append({'video_id': video_id, 'video_title': video_title, 'upload_date': upload_date, 'view_count': view_count, 'like_count': like_count, 'comment_count': comment_count, 'duration': duration}, ignore_index=True)
        
        try:
            if response['nextPageToken'] != None: #if none, it means it reached the last page and break out of it
                pageToken = "pageToken=" + response['nextPageToken']
        
        except:
            break

    return yt_df

# %%
yt_df = pd.DataFrame(columns=['video_id', 'video_title', 'upload_date', 'view_count', 'like_count', 'comment_count', 'duration'])

# %%
yt_df = get_videos(yt_df)
# Out:
# C:\Users\yo\AppData\Local\Temp\ipykernel_9880\1052936243.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   yt_df = yt_df.append({'video_id': video_id, 'video_title': video_title, 'upload_date': upload_date, 'view_count': view_count, 'like_count': like_count, 'comment_count': comment_count, 'duration': duration}, ignore_index=True)
# C:\Users\yo\AppData\Local\Temp\ipykernel_9880\1052936243.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   yt_df = yt_df.append({'video_id': video_id, 'video_title': video_title, 'upload_date': upload_date, 'view_count': view_count, 'like_count': like_count, 'comment_count': comment_count, 'duration': duration}, ignore_index=True)
# C:\Users\yo\AppData\Local\Temp\ipykernel_9880\1052936243.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   yt_df = yt_df.append({'video_id': video_id, 'video_title': video_title, 'upload_date': upload_date, 'view_count': view_count, 'like_count': like_count, 'comment_count': comment_count, 'duration': duration}, ignore_index=True)
# C:\Users\yo\AppData\Local\Temp\ipykernel_9880\1052936243.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   yt_df = yt_df.append({'video_id': video_id, 'video_title': video_title, 'upload_date': upload_date, 'view_count': view_count, 'like_count': like_count, 'comment_count': comment_count, 'duration': duration}, ignore_index=True)
# C:\Users\yo\AppData\Local\Temp\ipykernel_9880\1052936243.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   yt_df = yt_df.append({'video_id': video_id, 'video_title': video_title, 'upload_date': upload_date, 'view_count': view_count, 'like_count': like_count, 'comment_count': comment_count, 'duration': duration}, ignore_index=True)
# C:\Users\yo\AppData\Local\Temp\ipykernel_9880\1052936243.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   yt_df = yt_df.append({'video_id': video_id, 'video_title': video_title, 'upload_date': upload_date, 'view_count': view_count, 'like_count': like_count, 'comment_count': comment_count, 'duration': duration}, ignore_index=True)
# C:\Users\yo\AppData\Local\Temp\ipykernel_9880\1052936243.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   yt_df = yt_df.append({'video_id': video_id, 'video_title': video_title, 'upload_date': upload_date, 'view_count': view_count, 'like_count': like_count, 'comment_count': comment_count, 'duration': duration}, ignore_index=True)
# C:\Users\yo\AppData\Local\Temp\ipykernel_9880\1052936243.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   yt_df = yt_df.append({'video_id': video_id, 'video_title': video_title, 'upload_date': upload_date, 'view_count': view_count, 'like_count': like_count, 'comment_count': comment_count, 'duration': duration}, ignore_index=True)
# C:\Users\yo\AppData\Local\Temp\ipykernel_9880\1052936243.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   yt_df = yt_df.append({'video_id': video_id, 'video_title': video_title, 'upload_date': upload_date, 'view_count': view_count, 'like_count': like_count, 'comment_count': comment_count, 'duration': duration}, ignore_index=True)
# C:\Users\yo\AppData\Local\Temp\ipykernel_9880\1052936243.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   yt_df = yt_df.append({'video_id': video_id, 'video_title': video_title, 'upload_date': upload_date, 'view_count': view_count, 'like_count': like_count, 'comment_count': comment_count, 'duration': duration}, ignore_index=True)
# C:\Users\yo\AppData\Local\Temp\ipykernel_9880\1052936243.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   yt_df = yt_df.append({'video_id': video_id, 'video_title': video_title, 'upload_date': upload_date, 'view_count': view_count, 'like_count': like_count, 'comment_count': comment_count, 'duration': duration}, ignore_index=True)
# C:\Users\yo\AppData\Local\Temp\ipykernel_9880\1052936243.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   yt_df = yt_df.append({'video_id': video_id, 'video_title': video_title, 'upload_date': upload_date, 'view_count': view_count, 'like_count': like_count, 'comment_count': comment_count, 'duration': duration}, ignore_index=True)
# C:\Users\yo\AppData\Local\Temp\ipykernel_9880\1052936243.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   yt_df = yt_df.append({'video_id': video_id, 'video_title': video_title, 'upload_date': upload_date, 'view_count': view_count, 'like_count': like_count, 'comment_count': comment_count, 'duration': duration}, ignore_index=True)
# C:\Users\yo\AppData\Local\Temp\ipykernel_9880\1052936243.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   yt_df = yt_df.append({'video_id': video_id, 'video_title': video_title, 'upload_date': upload_date, 'view_count': view_count, 'like_count': like_count, 'comment_count': comment_count, 'duration': duration}, ignore_index=True)
# C:\Users\yo\AppData\Local\Temp\ipykernel_9880\1052936243.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   yt_df = yt_df.append({'video_id': video_id, 'video_title': video_title, 'upload_date': upload_date, 'view_count': view_count, 'like_count': like_count, 'comment_count': comment_count, 'duration': duration}, ignore_index=True)
# C:\Users\yo\AppData\Local\Temp\ipykernel_9880\1052936243.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   yt_df = yt_df.append({'video_id': video_id, 'video_title': video_title, 'upload_date': upload_date, 'view_count': view_count, 'like_count': like_count, 'comment_count': comment_count, 'duration': duration}, ignore_index=True)
# C:\Users\yo\AppData\Local\Temp\ipykernel_9880\1052936243.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   yt_df = yt_df.append({'video_id': video_id, 'video_title': video_title, 'upload_date': upload_date, 'view_count': view_count, 'like_count': like_count, 'comment_count': comment_count, 'duration': duration}, ignore_index=True)
# C:\Users\yo\AppData\Local\Temp\ipykernel_9880\1052936243.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   yt_df = yt_df.append({'video_id': video_id, 'video_title': video_title, 'upload_date': upload_date, 'view_count': view_count, 'like_count': like_count, 'comment_count': comment_count, 'duration': duration}, ignore_index=True)
# C:\Users\yo\AppData\Local\Temp\ipykernel_9880\1052936243.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   yt_df = yt_df.append({'video_id': video_id, 'video_title': video_title, 'upload_date': upload_date, 'view_count': view_count, 'like_count': like_count, 'comment_count': comment_count, 'duration': duration}, ignore_index=True)
# C:\Users\yo\AppData\Local\Temp\ipykernel_9880\1052936243.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   yt_df = yt_df.append({'video_id': video_id, 'video_title': video_title, 'upload_date': upload_date, 'view_count': view_count, 'like_count': like_count, 'comment_count': comment_count, 'duration': duration}, ignore_index=True)
# C:\Users\yo\AppData\Local\Temp\ipykernel_9880\1052936243.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   yt_df = yt_df.append({'video_id': video_id, 'video_title': video_title, 'upload_date': upload_date, 'view_count': view_count, 'like_count': like_count, 'comment_count': comment_count, 'duration': duration}, ignore_index=True)
# C:\Users\yo\AppData\Local\Temp\ipykernel_9880\1052936243.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   yt_df = yt_df.append({'video_id': video_id, 'video_title': video_title, 'upload_date': upload_date, 'view_count': view_count, 'like_count': like_count, 'comment_count': comment_count, 'duration': duration}, ignore_index=True)
# C:\Users\yo\AppData\Local\Temp\ipykernel_9880\1052936243.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   yt_df = yt_df.append({'video_id': video_id, 'video_title': video_title, 'upload_date': upload_date, 'view_count': view_count, 'like_count': like_count, 'comment_count': comment_count, 'duration': duration}, ignore_index=True)
# C:\Users\yo\AppData\Local\Temp\ipykernel_9880\1052936243.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   yt_df = yt_df.append({'video_id': video_id, 'video_title': video_title, 'upload_date': upload_date, 'view_count': view_count, 'like_count': like_count, 'comment_count': comment_count, 'duration': duration}, ignore_index=True)
# C:\Users\yo\AppData\Local\Temp\ipykernel_9880\1052936243.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   yt_df = yt_df.append({'video_id': video_id, 'video_title': video_title, 'upload_date': upload_date, 'view_count': view_count, 'like_count': like_count, 'comment_count': comment_count, 'duration': duration}, ignore_index=True)
# C:\Users\yo\AppData\Local\Temp\ipykernel_9880\1052936243.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   yt_df = yt_df.append({'video_id': video_id, 'video_title': video_title, 'upload_date': upload_date, 'view_count': view_count, 'like_count': like_count, 'comment_count': comment_count, 'duration': duration}, ignore_index=True)
# C:\Users\yo\AppData\Local\Temp\ipykernel_9880\1052936243.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   yt_df = yt_df.append({'video_id': video_id, 'video_title': video_title, 'upload_date': upload_date, 'view_count': view_count, 'like_count': like_count, 'comment_count': comment_count, 'duration': duration}, ignore_index=True)
# C:\Users\yo\AppData\Local\Temp\ipykernel_9880\1052936243.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   yt_df = yt_df.append({'video_id': video_id, 'video_title': video_title, 'upload_date': upload_date, 'view_count': view_count, 'like_count': like_count, 'comment_count': comment_count, 'duration': duration}, ignore_index=True)
# C:\Users\yo\AppData\Local\Temp\ipykernel_9880\1052936243.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   yt_df = yt_df.append({'video_id': video_id, 'video_title': video_title, 'upload_date': upload_date, 'view_count': view_count, 'like_count': like_count, 'comment_count': comment_count, 'duration': duration}, ignore_index=True)
# C:\Users\yo\AppData\Local\Temp\ipykernel_9880\1052936243.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   yt_df = yt_df.append({'video_id': video_id, 'video_title': video_title, 'upload_date': upload_date, 'view_count': view_count, 'like_count': like_count, 'comment_count': comment_count, 'duration': duration}, ignore_index=True)
# C:\Users\yo\AppData\Local\Temp\ipykernel_9880\1052936243.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   yt_df = yt_df.append({'video_id': video_id, 'video_title': video_title, 'upload_date': upload_date, 'view_count': view_count, 'like_count': like_count, 'comment_count': comment_count, 'duration': duration}, ignore_index=True)
# C:\Users\yo\AppData\Local\Temp\ipykernel_9880\1052936243.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   yt_df = yt_df.append({'video_id': video_id, 'video_title': video_title, 'upload_date': upload_date, 'view_count': view_count, 'like_count': like_count, 'comment_count': comment_count, 'duration': duration}, ignore_index=True)
# C:\Users\yo\AppData\Local\Temp\ipykernel_9880\1052936243.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   yt_df = yt_df.append({'video_id': video_id, 'video_title': video_title, 'upload_date': upload_date, 'view_count': view_count, 'like_count': like_count, 'comment_count': comment_count, 'duration': duration}, ignore_index=True)
# C:\Users\yo\AppData\Local\Temp\ipykernel_9880\1052936243.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   yt_df = yt_df.append({'video_id': video_id, 'video_title': video_title, 'upload_date': upload_date, 'view_count': view_count, 'like_count': like_count, 'comment_count': comment_count, 'duration': duration}, ignore_index=True)
# C:\Users\yo\AppData\Local\Temp\ipykernel_9880\1052936243.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   yt_df = yt_df.append({'video_id': video_id, 'video_title': video_title, 'upload_date': upload_date, 'view_count': view_count, 'like_count': like_count, 'comment_count': comment_count, 'duration': duration}, ignore_index=True)
# C:\Users\yo\AppData\Local\Temp\ipykernel_9880\1052936243.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   yt_df = yt_df.append({'video_id': video_id, 'video_title': video_title, 'upload_date': upload_date, 'view_count': view_count, 'like_count': like_count, 'comment_count': comment_count, 'duration': duration}, ignore_index=True)
# C:\Users\yo\AppData\Local\Temp\ipykernel_9880\1052936243.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   yt_df = yt_df.append({'video_id': video_id, 'video_title': video_title, 'upload_date': upload_date, 'view_count': view_count, 'like_count': like_count, 'comment_count': comment_count, 'duration': duration}, ignore_index=True)
# C:\Users\yo\AppData\Local\Temp\ipykernel_9880\1052936243.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   yt_df = yt_df.append({'video_id': video_id, 'video_title': video_title, 'upload_date': upload_date, 'view_count': view_count, 'like_count': like_count, 'comment_count': comment_count, 'duration': duration}, ignore_index=True)
# C:\Users\yo\AppData\Local\Temp\ipykernel_9880\1052936243.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   yt_df = yt_df.append({'video_id': video_id, 'video_title': video_title, 'upload_date': upload_date, 'view_count': view_count, 'like_count': like_count, 'comment_count': comment_count, 'duration': duration}, ignore_index=True)
# C:\Users\yo\AppData\Local\Temp\ipykernel_9880\1052936243.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   yt_df = yt_df.append({'video_id': video_id, 'video_title': video_title, 'upload_date': upload_date, 'view_count': view_count, 'like_count': like_count, 'comment_count': comment_count, 'duration': duration}, ignore_index=True)
# C:\Users\yo\AppData\Local\Temp\ipykernel_9880\1052936243.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   yt_df = yt_df.append({'video_id': video_id, 'video_title': video_title, 'upload_date': upload_date, 'view_count': view_count, 'like_count': like_count, 'comment_count': comment_count, 'duration': duration}, ignore_index=True)
# C:\Users\yo\AppData\Local\Temp\ipykernel_9880\1052936243.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   yt_df = yt_df.append({'video_id': video_id, 'video_title': video_title, 'upload_date': upload_date, 'view_count': view_count, 'like_count': like_count, 'comment_count': comment_count, 'duration': duration}, ignore_index=True)
# C:\Users\yo\AppData\Local\Temp\ipykernel_9880\1052936243.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   yt_df = yt_df.append({'video_id': video_id, 'video_title': video_title, 'upload_date': upload_date, 'view_count': view_count, 'like_count': like_count, 'comment_count': comment_count, 'duration': duration}, ignore_index=True)
# C:\Users\yo\AppData\Local\Temp\ipykernel_9880\1052936243.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   yt_df = yt_df.append({'video_id': video_id, 'video_title': video_title, 'upload_date': upload_date, 'view_count': view_count, 'like_count': like_count, 'comment_count': comment_count, 'duration': duration}, ignore_index=True)
# C:\Users\yo\AppData\Local\Temp\ipykernel_9880\1052936243.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   yt_df = yt_df.append({'video_id': video_id, 'video_title': video_title, 'upload_date': upload_date, 'view_count': view_count, 'like_count': like_count, 'comment_count': comment_count, 'duration': duration}, ignore_index=True)
# C:\Users\yo\AppData\Local\Temp\ipykernel_9880\1052936243.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   yt_df = yt_df.append({'video_id': video_id, 'video_title': video_title, 'upload_date': upload_date, 'view_count': view_count, 'like_count': like_count, 'comment_count': comment_count, 'duration': duration}, ignore_index=True)
# C:\Users\yo\AppData\Local\Temp\ipykernel_9880\1052936243.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   yt_df = yt_df.append({'video_id': video_id, 'video_title': video_title, 'upload_date': upload_date, 'view_count': view_count, 'like_count': like_count, 'comment_count': comment_count, 'duration': duration}, ignore_index=True)
# C:\Users\yo\AppData\Local\Temp\ipykernel_9880\1052936243.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   yt_df = yt_df.append({'video_id': video_id, 'video_title': video_title, 'upload_date': upload_date, 'view_count': view_count, 'like_count': like_count, 'comment_count': comment_count, 'duration': duration}, ignore_index=True)
# C:\Users\yo\AppData\Local\Temp\ipykernel_9880\1052936243.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   yt_df = yt_df.append({'video_id': video_id, 'video_title': video_title, 'upload_date': upload_date, 'view_count': view_count, 'like_count': like_count, 'comment_count': comment_count, 'duration': duration}, ignore_index=True)
# C:\Users\yo\AppData\Local\Temp\ipykernel_9880\1052936243.py:48: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   yt_df = yt_df.append({'video_id': video_id, 'video_title': video_title, 'upload_date': upload_date, 'view_count': view_count, 'like_count': like_count, 'comment_count': comment_count, 'duration': duration}, ignore_index=True)

# %%
yt_df
# Out:
#        video_id                                        video_title  \
# 0   KKH08BnAUBY             El Metodo Rebord #47 - Máximo Kirchner
# 1   FMO13F3Btd0       El Metodo Rebord #46 - Emmanuel Alvarez Agis
# 2   Wevw4zbhScM                 El Metodo Rebord #45 - El Bananero
# 3   yWlSbdnh6LA   Conclave #3 - Luquitas Rodriguez y Guille Aquino
# 4   FStaQVTWz2w            El Metodo Rebord #44 - Osvaldo Carnival
# 5   ICbnfgarTNQ            El Metodo Rebord #43 - Mariana Enríquez
# 6   cuykltGqOP4            El Metodo Rebord #42 - Cristian Ritondo
# 7   hQvveEsbSJE     Conclave #2 - Santi Maratea y Ofelia Fernández
# 8   -tD9dcvm9LQ  Conclave #1 - Carlos Maslaton e Iván Schargrodsky
# 9   j8i2dJ_fuJE         El Metodo Rebord #41 - Emmanuel Horvilleur
# 10  zEyv08P7D9E                El Metodo Rebord #40 - Sergio Berni
# 11  jGs9jwx3u_M              El Metodo Rebord #39 - Paulina Cocina
# 12  cUxQQU45cQ4       El Metodo Rebord #38 - Jorge 'El Turco' Asis
# 13  ZhqKsIDmVrs       El Metodo Rebord #37 - Fernando Vaca Narvaja
# 14  BGCQ2Q4Q0w4               El Metodo Rebord #36 - Santi Maratea
# 15  DW3fnTN2zy4                El Metodo Rebord #35 - Carlos Pagni
# 16  h9YiNRCmDBY            El Metodo Rebord #34 - Jorge Capitanich
# 17  xBh9Rr6QHmI              El Metodo Rebord #33 - Jorge Altamira
# 18  PbOTsaLBlfE                El Metodo Rebord #32 - Juan Grabois
# 19  CMhabU13GFE                 El Metodo Rebord #31- Felipe Pigna
# 20  4I37WuzVI3w             El Metodo Rebord #30 - Maria O'Donnell
# 21  VgKcXLuhuj0            El Metodo Rebord #29 - Guillermo Moreno
# 22  KcipL7fIBUU   El Metodo Rebord #28 - Fernando 'Pato' Galmarini
# 23  wioqxlmXg8E              El Metodo Rebord #27 - Franco Rinaldi
# 24  1gaC5scO8E4             El Metodo Rebord #26 - Julia Mengolini
# 25  ywVT9CPNGPI       El Metodo Rebord #25 - Juariu (Vicky Braier)
# 26  OSeKhOS8ryg                      El Metodo Rebord #24 - Dillom
# 27  6ogXEIrh4uo               El Metodo Rebord #23 - Sergio Chodos
# 28  4OD-ZgrWedE   El Metodo Rebord #22 -  Cumbio (Agustina Vivero)
# 29  zm49034Y7Zc             El Metodo Rebord #21 - Mario Pergolini
# 30  OKbqQ5OQNXE               El Metodo Rebord #20 - Carlos Corach
# 31  F0mS8jzzVkE        El Metodo Rebord #19 - Gustavo Grobocopatel
# 32  P3viompdb5Y             El Metodo Rebord #18 - Marcela Feudale
# 33  og12qCy5zcY           El Metodo Rebord #17 - Iván Schargrodsky
# 34  6b-kKh2ldXg                  El Metodo Rebord #16 - Damián Kuc
# 35  Y1YuKsS9vYA             El Metodo Rebord #15 - Leandro Santoro
# 36  ViVQJN5IfK8           El Metodo Rebord #14 - Diego Lagomarsino
# 37  Bjx4rBuDOL4             El Metodo Rebord #13 - Adrián Lakerman
# 38  rskswNE_qVc               El Metodo Rebord #12 - Matías Kulfas
# 39  oJoD0VI4Fiw             El Metodo Rebord #11 - Juan Cruz Komar
# 40  AbNyHhxq5ZU                   El Metodo Rebord #10 - Nati Jota
# 41  DEtMSDpn1ws                  El Metodo Rebord #9 - Mayra Arena
# 42  WGWnSL1rFoY               El Metodo Rebord #8 - Fede Simonetti
# 43  yeYrHc5oOsU              El Metodo Rebord #7 - Carlos Maslaton
# 44  pOvpca1-VqM            El Metodo Rebord #6 - Georgina Orellano
# 45  n8CNI_zB4Rg                El Metodo Rebord #5 - Guille Aquino
